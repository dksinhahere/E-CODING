# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("./Titanic-Dataset.csv")
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
min = np.min(dataset["Age"])
max = np.max(dataset["Age"])

# %%
range = max - min

# %%
range
# Out:
# np.float64(79.58)

# %%
group1 = np.array([75, 65, 73, 68, 72, 76])
group2 = np.array([90, 47, 43, 96, 93, 51])

# %%
no = np.array([1, 2, 3, 4, 5, 6])

# %%
mean = np.mean(group1)

plt.figure(figsize=(10, 5))
plt.scatter(group1, no, color="green", label="GROUP_1")
plt.scatter(group2, no, color="red", label="GROUP_2")
plt.axvline(mean, color="blue", label="mean")
plt.legend()
plt.show()
