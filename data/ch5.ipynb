# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sec_1 = np.array([75, 65, 73, 68, 72, 76])
sec_2 = np.array([90, 47, 43, 96, 93, 51])
no = np.array([1, 2, 3, 4, 5, 6])

# %%
m1 = np.mean(sec_1)
m2 = np.mean(sec_2)

# %%
### Mean Absolute division

# %%
n1 = np.sum(np.abs(sec_1-m1))/len(sec_1)
n2 = np.sum(np.abs(sec_2-m2))/len(sec_2)

# %%
### Stander Division

# %%
np.std(sec_1), np.std(sec_2)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %%
np.var(sec_1), np.var(sec_2)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
dataset = pd.read_csv("./Titanic-Dataset.csv")

# %%
dataset["Age"].std()
# Out:
# np.float64(14.526497332334042)

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.histplot(x="Age", data=dataset)
plt.show()
