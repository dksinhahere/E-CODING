# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr = np.array([4, 5, 6, 7, 8, 9, 2, 3, 4, 5])

# %%
_sum_ = np.sum(arr)

# %%
ave = _sum_ / len(arr)

# %%
ave
# Out:
# np.float64(5.3)

# %%
_ave_ = np.mean(arr)

# %%
_ave_
# Out:
# np.float64(5.3)

# %%
dataset = pd.read_csv("./Titanic-Dataset.csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
mean_age = np.mean(dataset["Age"])

# %%
mean_age
# Out:
# np.float64(29.69911764705882)

# %%
_age_mean_ = np.mean(dataset["Age"])
sns.histplot(x="Age", data=dataset, bins=range(int(dataset["Age"].min()), int(dataset["Age"].max()), 5))
plt.axvline(_age_mean_, color="red")
plt.show()

# %%
dataset["Age"].min()
# Out:
# np.float64(0.42)

# %%
dataset['Age'].max()
# Out:
# np.float64(80.0)
