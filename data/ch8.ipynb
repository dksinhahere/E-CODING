# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Titanic-Dataset.csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
sns.histplot(x="Age", data=df)
plt.show()

# %%
df["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
data = np.random.normal(0, 100, 100)
data = pd.DataFrame({"x":data})

# %%
data.head(3)
# Out:
#            x
# 0  82.480497
# 1 -15.997377
# 2 -37.886806

# %%
data["x"].skew()
# Out:
# np.float64(0.010837925571190751)

# %%
sns.histplot(x="x", data=data)
plt.show()

# %%
data["x"].mean(), data["x"].median(), data["x"].mode()
# Out:
# (np.float64(-16.74301362792796),
#  np.float64(-12.385890695836554),
#  0    -276.096247
#  1    -196.456572
#  2    -160.142378
#  3    -152.092094
#  4    -149.514883
#           ...
#  95    148.498025
#  96    156.451944
#  97    161.403502
#  98    164.317660
#  99    200.142548
#  Name: x, Length: 100, dtype: float64)

# %%
df["Age"].mean(), df["Age"].median(), df["Age"].mode()[0]
# Out:
# (np.float64(29.69911764705882), np.float64(28.0), np.float64(24.0))
