# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/refs/heads/master/titanic.csv")

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df1 = pd.read_html("data/d1.html")

# %%
df1
# Out:
# [    ID         Full Name  Username                         Email  \
#  0    1      Aarav Sharma   aarav_s      aarav.sharma@example.com
#  1    2        Diya Verma    diya_v        diya.verma@example.com
#  2    3       Kabir Singh   kabir_s       kabir.singh@example.com
#  3    4      Ananya Gupta  ananya_g      ananya.gupta@example.com
#  4    5       Rohan Mehta   rohan_m       rohan.mehta@example.com
#  5    6       Ishita Nair  ishita_n       ishita.nair@example.com
#  6    7        Vikram Rao  vikram_r        vikram.rao@example.com
#  7    8        Meera Iyer   meera_i        meera.iyer@example.com
#  8    9      Aditya Joshi  aditya_j      aditya.joshi@example.com
#  9   10         Sara Khan    sara_k         sara.khan@example.com
#  10  11        Neel Patel    neel_p        neel.patel@example.com
#  11  12         Pooja Das   pooja_d         pooja.das@example.com
#  12  13       Arjun Reddy   arjun_r       arjun.reddy@example.com
# ...

# %%
df3 = pd.read_json("data/d2.json")

# %%
df3.head(3)
# Out:
#                title generated_on  \
# 0  Mini Student Data   2026-02-04
# 1  Mini Student Data   2026-02-04
# 2  Mini Student Data   2026-02-04
#
#                                             students
# 0  {'id': 1, 'name': 'Aarav Sharma', 'cgpa': 8.2,...
# 1  {'id': 2, 'name': 'Diya Verma', 'cgpa': 6.1, '...
# 2  {'id': 3, 'name': 'Kabir Singh', 'cgpa': 7.5, ...

# %%
df.to_csv("data/d4.csv", index=None, sep="|")

# %%
df = pd.read_csv("data/d4.csv", sep="|")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head(1)
# Out:
#    passengerid  survived  pclass                     name   sex   age  sibsp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    parch     ticket  fare cabin embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
x = df[["age", "pclass"]]

# %%
x
# Out:
#       age  pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
df["name"] = [x.lower() for x in df["name"]]

# %%
df.head(5)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df["family_size"] = df["sibsp"] + df["parch"]

# %%
df.head(5)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  family_size
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...

# %%
df["fair_per_person"] = df["fare"] / (df["family_size"]+1)

# %%
df.head(3)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
#
#    parch            ticket     fare cabin embarked  family_size  \
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
#
#    fair_per_person
# 0          3.62500
# 1         35.64165
# 2          7.92500

# %%
df.head(5)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  family_size  \
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...

# %%
df["alone"] = df["family_size"].apply(lambda x: False if x > 0 else True)

# %%
df.head(5)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            braund, mr. owen harris    male  22.0      1
# 1  cumings, mrs. john bradley (florence briggs th...  female  38.0      1
# 2                             heikkinen, miss. laina  female  26.0      0
# 3       futrelle, mrs. jacques heath (lily may peel)  female  35.0      1
# 4                           allen, mr. william henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked  family_size  \
# 0      0         A/5 21171   7.2500   NaN        S            1
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            0
# ...
