# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("./Titanic-Dataset.csv")

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset["Fare"].mode().iloc[0]
# Out:
# np.float64(8.05)

# %%
dataset["Fare"].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
dataset["Fare"].head(3)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# Name: Fare, dtype: float64

# %%
dataset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dataset["Cabin"].value_counts().loc[[dataset["Cabin"].mode().iloc[0]]].plot(kind="bar")
# Out:
# <Axes: xlabel='Cabin'>

# %%
dataset["Cabin"].head(10).value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Cabin'>

# %%
mo = dataset["Cabin"].mode().iloc[0]

# %%
mo = dataset["Cabin"].mode().iloc[0]
sns.histplot(x="Cabin", data=dataset, bins=[i for i in range(int(0), int(81), 1)])
plt.axvline(x=mo, color='red')
plt.show()
